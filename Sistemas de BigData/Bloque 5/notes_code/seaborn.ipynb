# %%
import seaborn as sns

paleta = sns.color_palette()
sns.palplot(paleta)

# %% [markdown]
# [Pre configured styles](https://seaborn.pydata.org/tutorial/aesthetics.html)
#
# [Color Paletes](https://seaborn.pydata.org/tutorial/color_palettes.html)

# %%
import pandas as pd

# Carregam les dades de flors iris
df = sns.load_dataset("iris")

#Assignam un estil al gràfic (opcional)
sns.set_style("whitegrid")

# Cream un diagrama de barres
sns.barplot(data=df, x='species', y='petal_length')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.barplot(data=df, x='species', y='petal_length',
   palette='pastel', errorbar=None)
# Out:
# /var/folders/92/nk5ygsc173b8m7dkjszp_kvh0000gn/T/ipykernel_4656/3716031084.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='species', y='petal_length',
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
df2 = sns.load_dataset("tips")
sns.barplot(data=df2, x='day', y='tip', hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(data=df, x='species', y='petal_length', hue='species', palette='pastel', errorbar=None)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.scatterplot(data=df, x='species', y='petal_length', hue='species',
   palette='bright')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(data=df, x='species', y='petal_length', hue='species',
   palette='bright')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
import matplotlib.pyplot as plt

etiquetes = ['Categoria 1', 'Categoria 2', 'Categoria 3', 'Categoria 4']
valors = [50, 80, 20, 30]
colors = sns.color_palette('pastel')
sns.set_style("dark")
plt.figure(figsize=(6, 6))
plt.pie(valors, labels=etiquetes, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Gràfic circular (Matplotlib i Seaborn)')
plt.show()

# %% [markdown]
# [Seaborn Documentation](https://seaborn.pydata.org/)
#
# [Seaborn examples](https://python-charts.com/es/seaborn/)
