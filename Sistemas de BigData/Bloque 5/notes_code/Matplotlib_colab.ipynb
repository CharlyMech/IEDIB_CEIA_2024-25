# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

ax1.hist(np.random.randn(100), bins = 20, color = 'k', alpha= 0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
ax3.plot(np.random.randn(50).cumsum(),'k--')

plt.show()

# %%
# Dades d'exemple per als gràfics de barres i el gràfic circular
etiquetes = ['Categoria 1', 'Categoria 2', 'Categoria 3', 'Categoria 4']
valors = [50, 80, 20, 30]

# %%
# Crea el gràfic de barres verticals amb Matplotlib
plt.figure(figsize=(8, 6))
plt.bar(etiquetes, valors, color='skyblue')
plt.title('Gràfic de barres verticals (Matplotlib)')
plt.xlabel('Categories')
plt.ylabel('Valors')
plt.show()

# %%
# Crea el gràfic de barres horitzontals amb Matplotlib
plt.figure(figsize=(8, 6))
plt.barh(etiquetes, valors, color='skyblue')
plt.title('Gràfic de barres hotizontals (Matplotlib)')
plt.xlabel('Valors')
plt.ylabel('Categories')
plt.show()

# %%
# Crea el diagrama circular (o de pastís) amb Matplotlib
plt.figure(figsize=(6, 6))
plt.pie(valors, labels=etiquetes, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightyellow', 'lightgreen'])
plt.title('Gràfic circular (Matplotlib)')
plt.show()

# %%
# squarify no està instal·lat en els servidors de Google, ho hem de fer amb pip
# !pip install squarify

# %%
import matplotlib.pyplot as plt
import squarify

# Dades d'exemple
etiquetes = ['Categoria 1', 'Categoria 2', 'Categoria 3', 'Categoria 4', 'Categoria 5', 'Categoria 6']
valors = [250, 120, 280, 320, 140, 95]
colors = ['#91DCEA', '#64CDCC', '#5FBB68','#F9D23C', '#F9A729', '#FD6F30']

# Treemap
squarify.plot(sizes = valors, label = etiquetes, color = colors )

# Eliminar els eixos:
plt.axis("off")

plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = "En un lugar de la Mancha, de cuyo nombre no quiero acordarme, no ha mucho \
tiempo que vivía un hidalgo de los de lanza en astillero, adarga antigua, \
rocín flaco y galgo corredor."

wc = WordCloud(width = 300, height = 300).generate(text)

# Elimina els eixos i mostra les dades com una imatge
plt.axis("off")
plt.imshow(wc, interpolation = "bilinear")

plt.show()
